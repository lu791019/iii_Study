# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime as dt
from datetime import timedelta,time
import csv

# %%
dirname = 'E:/iii_PROJECT/UTIME_ML_PREDICT'

f_ct = os.path.join(dirname,'Summary.xlsx')

ct = pd.read_excel(f_ct)

# %%
ct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97089 entries, 0 to 97088
# Data columns (total 28 columns):
# CSDP            97089 non-null int64
# PNO             97089 non-null int64
# CDATE           97089 non-null object
# ITEM            97089 non-null int64
# SEQNO           97089 non-null int64
# SNO2            97089 non-null int64
# SCRN            97089 non-null object
# BDATE           97089 non-null object
# EDATE           97076 non-null object
# ORDERDR         97089 non-null object
# MD_NO           97089 non-null int64
# PP_NO           97089 non-null object
# MODEL_NAME      97020 non-null object
# STATION_NAME    97089 non-null object
# PLACE           97089 non-null object
# CASENO          97089 non-null int64
# LINKNO          97089 non-null int64
# AMOUNT          96749 non-null float64
# NHI_COST        0 non-null float64
# IO              97089 non-null object
# DEPT            97087 non-null object
# PRICE           0 non-null float64
# ...

# %%
ct.columns
# Out:
# Index(['CSDP', 'PNO', 'CDATE', 'ITEM', 'SEQNO', 'SNO2', 'SCRN', 'BDATE',
#        'EDATE', 'ORDERDR', 'MD_NO', 'PP_NO', 'MODEL_NAME', 'STATION_NAME',
#        'PLACE', 'CASENO', 'LINKNO', 'AMOUNT', 'NHI_COST', 'IO', 'DEPT',
#        'PRICE', 'UTIME', 'ITEM_CNT', 'SEX', 'AGE', 'POS', 'Tool'],
#       dtype='object')

# %%
ct.head()
# Out:
#    CSDP       PNO                  CDATE   ITEM       SEQNO  SNO2  \
# 0  3580  29522338  2017/10/2 上午 12:00:00  70022  2060178785     1
# 1  3580  17656486  2017/10/2 上午 12:00:00  70018  2060178819     1
# 2  3580  35951053  2017/10/2 上午 12:00:00  79993  2060178851     1
# 3  3580   3652066  2017/10/2 上午 12:00:00  79993  2060178855     1
# 4  3580   6780233  2017/10/2 上午 12:00:00  79994  2060178878     1
#
#                     SCRN                  BDATE                  EDATE  \
# 0  2019/7/17 下午 02:42:56  2017/10/2 上午 08:29:00  2017/10/2 上午 08:44:26
# 1  2019/7/17 下午 02:42:51  2017/10/2 上午 09:03:00  2017/10/2 上午 09:13:33
# 2  2019/7/17 下午 02:42:54  2017/10/2 上午 09:30:00  2017/10/2 上午 09:59:21
# 3  2019/7/17 下午 02:42:39  2017/10/2 上午 09:34:00  2017/10/2 上午 10:18:21
# 4  2019/7/17 下午 02:42:39  2017/10/2 上午 09:47:00  2017/10/2 上午 10:01:39
#
#   ORDERDR  ...  NHI_COST IO DEPT PRICE                  UTIME  ITEM_CNT  SEX  \
# ...

# %%
ct1=ct

# %%
ct1.head()
# Out:
#    CSDP       PNO                  CDATE   ITEM       SEQNO  SNO2  \
# 0  3580  29522338  2017/10/2 上午 12:00:00  70022  2060178785     1
# 1  3580  17656486  2017/10/2 上午 12:00:00  70018  2060178819     1
# 2  3580  35951053  2017/10/2 上午 12:00:00  79993  2060178851     1
# 3  3580   3652066  2017/10/2 上午 12:00:00  79993  2060178855     1
# 4  3580   6780233  2017/10/2 上午 12:00:00  79994  2060178878     1
#
#                     SCRN                  BDATE                  EDATE  \
# 0  2019/7/17 下午 02:42:56  2017/10/2 上午 08:29:00  2017/10/2 上午 08:44:26
# 1  2019/7/17 下午 02:42:51  2017/10/2 上午 09:03:00  2017/10/2 上午 09:13:33
# 2  2019/7/17 下午 02:42:54  2017/10/2 上午 09:30:00  2017/10/2 上午 09:59:21
# 3  2019/7/17 下午 02:42:39  2017/10/2 上午 09:34:00  2017/10/2 上午 10:18:21
# 4  2019/7/17 下午 02:42:39  2017/10/2 上午 09:47:00  2017/10/2 上午 10:01:39
#
#   ORDERDR  ...  NHI_COST IO DEPT PRICE                  UTIME  ITEM_CNT  SEX  \
# ...

# %%
ct1['BDATE'] = ct1['BDATE'].str.replace('下午',' PM ')

# %%
ct1['BDATE'] = ct1['BDATE'].str.replace('上午',' AM ')

# %%
ct1['EDATE'] = ct1['EDATE'].str.replace('下午',' PM ')
ct1['EDATE'] = ct1['EDATE'].str.replace('上午',' AM ')

# %%
ct1['UTIME'] = ct1['UTIME'].str.replace('下午',' PM ')
ct1['UTIME'] = ct1['UTIME'].str.replace('上午',' AM ')

# %%
ct1['SCRN'] = ct1['SCRN'].str.replace('下午',' PM ')
ct1['SCRN'] = ct1['SCRN'].str.replace('上午',' AM ')

# %%
ct1['CDATE'] = ct1['CDATE'].str.replace('下午',' PM ')
ct1['CDATE'] = ct1['CDATE'].str.replace('上午',' AM ')

# %%
ct1['BDATE'] = pd.to_datetime(ct1['BDATE'],format='%Y/%m/%d %p %I:%M:%S')

# %%
ct1['EDATE'] = pd.to_datetime(ct1['EDATE'],format='%Y/%m/%d %p %I:%M:%S')

# %%
ct1['UTIME'] = pd.to_datetime(ct1['UTIME'],format='%Y/%m/%d %p %I:%M:%S')

# %%
ct1['SCRN'] = pd.to_datetime(ct1['SCRN'],format='%Y/%m/%d %p %I:%M:%S')

# %%
ct1['CDATE'] = pd.to_datetime(ct1['CDATE'],format='%Y/%m/%d %p %I:%M:%S')

# %%
ct1[ct1['BDATE']=='00:00:00']
# Out:
# Empty DataFrame
# Columns: [CSDP, PNO, CDATE, ITEM, SEQNO, SNO2, SCRN, BDATE, EDATE, ORDERDR, MD_NO, PP_NO, MODEL_NAME, STATION_NAME, PLACE, CASENO, LINKNO, AMOUNT, NHI_COST, IO, DEPT, PRICE, UTIME, ITEM_CNT, SEX, AGE, POS, Tool]
# Index: []
#
# [0 rows x 28 columns]

# %%
ct1['Target_time'] = ct1['EDATE']-ct1['BDATE']

# %%
ct1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97089 entries, 0 to 97088
# Data columns (total 29 columns):
# CSDP            97089 non-null int64
# PNO             97089 non-null int64
# CDATE           97089 non-null datetime64[ns]
# ITEM            97089 non-null int64
# SEQNO           97089 non-null int64
# SNO2            97089 non-null int64
# SCRN            97089 non-null datetime64[ns]
# BDATE           97089 non-null datetime64[ns]
# EDATE           97076 non-null datetime64[ns]
# ORDERDR         97089 non-null object
# MD_NO           97089 non-null int64
# PP_NO           97089 non-null object
# MODEL_NAME      97020 non-null object
# STATION_NAME    97089 non-null object
# PLACE           97089 non-null object
# CASENO          97089 non-null int64
# LINKNO          97089 non-null int64
# AMOUNT          96749 non-null float64
# NHI_COST        0 non-null float64
# IO              97089 non-null object
# DEPT            97087 non-null object
# ...

# %%
ct1.columns
# Out:
# Index(['CSDP', 'PNO', 'CDATE', 'ITEM', 'SEQNO', 'SNO2', 'SCRN', 'BDATE',
#        'EDATE', 'ORDERDR', 'MD_NO', 'PP_NO', 'MODEL_NAME', 'STATION_NAME',
#        'PLACE', 'CASENO', 'LINKNO', 'AMOUNT', 'NHI_COST', 'IO', 'DEPT',
#        'PRICE', 'UTIME', 'ITEM_CNT', 'SEX', 'AGE', 'POS', 'Tool',
#        'Target_time'],
#       dtype='object')

# %%
ct1.to_csv('CT.Summary.csv',columns=['CSDP', 'PNO', 'CDATE', 'ITEM', 'SEQNO', 'SNO2', 'SCRN', 'BDATE',
       'EDATE', 'ORDERDR', 'MD_NO', 'PP_NO', 'MODEL_NAME', 'STATION_NAME',
       'PLACE', 'CASENO', 'LINKNO', 'AMOUNT', 'NHI_COST', 'IO', 'DEPT',
       'PRICE', 'UTIME', 'ITEM_CNT', 'SEX', 'AGE', 'POS', 'Tool',
       'Target_time'],index=False)

# %%
pwd
# Out:
# 'C:\\Users\\Big data\\iii_report_HospitalStudy\\iii_project_ML_predict'

# %%
'''import mysql.connector

conn=mysql.connector.connect(database='db_test',host='10.120.14.100',user='root',password = 'Qqqq@123')'''
# Out:
# "import mysql.connector\n\nconn=mysql.connector.connect(database='db_test',host='10.120.14.100',user='root',password = 'Qqqq@123')"

# %%
from sqlalchemy import create_engine
#engine=create_engine('sqlite:///./cnblogblog.db',echo=True)
engine = create_engine('mysql+mysqlconnector://root:Lu,77251@10.120.14.100:3306/db_test')
engine
# Out:
# Engine(mysql+mysqlconnector://root:***@10.120.14.100:3306/db_test)

# %% [markdown]
# ### LINUX指令來確認:
# #### 確認root 底下的使用者: SELECT host FROM mysql.user WHERE User = 'account';
# #### 新增使用者: CREATE USER 'account'@'10.120.14.23' IDENTIFIED BY 'Lu,77251';
# #### 開通權限:  GRANT ALL PRIVILEGES ON *.* TO 'root'@'10.120.14.23';

# %% [markdown]
# # TEST1  DF直接寫入

# %%
try:
    df = ct1
    df.to_sql('test1',con=engine,if_exists='replace',index=False)
except Exception as e:
    print(e)

# %%
sql = 'select * from test1;'
df_test = pd.read_sql_query(sql,engine)
df_test
# Out:
#        CSDP       PNO      CDATE   ITEM       SEQNO  SNO2                SCRN  \
# 0      3580  29522338 2017-10-02  70022  2060178785     1 2019-07-17 14:42:56
# 1      3580  17656486 2017-10-02  70018  2060178819     1 2019-07-17 14:42:51
# 2      3580  35951053 2017-10-02  79993  2060178851     1 2019-07-17 14:42:54
# 3      3580   3652066 2017-10-02  79993  2060178855     1 2019-07-17 14:42:39
# 4      3580   6780233 2017-10-02  79994  2060178878     1 2019-07-17 14:42:39
# 5      3580   1728878 2017-10-02  79993  2060178906     1 2019-07-17 14:42:39
# 6      3580   7648863 2017-10-02  79993  2060178923     1 2019-07-17 14:42:56
# 7      3580  17175480 2017-10-02  79993  2060179006     1 2019-07-17 14:42:55
# 8      3580  22332654 2017-10-02  79993  2060179163     1 2019-07-17 14:42:43
# 9      3580  37147078 2017-10-02  79993  2060179176     1 2019-07-17 14:42:40
# 10     3580  21024981 2017-10-02  70008  2060179178     1 2019-07-17 14:42:40
# ...

# %% [markdown]
# ### [TEST1] df_test 和本機端的DF比較

# %%
df
# Out:
#        CSDP       PNO      CDATE   ITEM       SEQNO  SNO2                SCRN  \
# 0      3580  29522338 2017-10-02  70022  2060178785     1 2019-07-17 14:42:56
# 1      3580  17656486 2017-10-02  70018  2060178819     1 2019-07-17 14:42:51
# 2      3580  35951053 2017-10-02  79993  2060178851     1 2019-07-17 14:42:54
# 3      3580   3652066 2017-10-02  79993  2060178855     1 2019-07-17 14:42:39
# 4      3580   6780233 2017-10-02  79994  2060178878     1 2019-07-17 14:42:39
# 5      3580   1728878 2017-10-02  79993  2060178906     1 2019-07-17 14:42:39
# 6      3580   7648863 2017-10-02  79993  2060178923     1 2019-07-17 14:42:56
# 7      3580  17175480 2017-10-02  79993  2060179006     1 2019-07-17 14:42:55
# 8      3580  22332654 2017-10-02  79993  2060179163     1 2019-07-17 14:42:43
# 9      3580  37147078 2017-10-02  79993  2060179176     1 2019-07-17 14:42:40
# 10     3580  21024981 2017-10-02  70008  2060179178     1 2019-07-17 14:42:40
# ...

# %% [markdown]
# # TEST2 將CSV匯出在寫入

# %%
dirname = 'E:/iii_PROJECT/UTIME_ML_PREDICT'
f_ct01 = os.path.join('CTtimeright.csv')
ct01 = pd.read_csv(f_ct_csv)

# %%
ct01.columns
# Out:
# Index(['CSDP', 'PNO', 'CDATE', 'ITEM', 'SEQNO', 'SNO2', 'SCRN', 'BDATE',
#        'EDATE', 'ORDERDR', 'MD_NO', 'PP_NO', 'MODEL_NAME', 'STATION_NAME',
#        'PLACE', 'CASENO', 'LINKNO', 'AMOUNT', 'NHI_COST', 'IO', 'DEPT',
#        'PRICE', 'UTIME', 'ITEM_CNT', 'SEX', 'AGE', 'POS', 'Tool',
#        'Target_time'],
#       dtype='object')

# %%
ct01.to_csv('CTtest',columns=['CSDP', 'PNO', 'CDATE', 'ITEM', 'SEQNO', 'SNO2', 'SCRN', 'BDATE',
       'EDATE', 'ORDERDR', 'MD_NO', 'PP_NO', 'MODEL_NAME', 'STATION_NAME',
       'PLACE', 'CASENO', 'LINKNO', 'AMOUNT', 'NHI_COST', 'IO', 'DEPT',
       'PRICE', 'UTIME', 'ITEM_CNT', 'SEX', 'AGE', 'POS', 'Tool',
       'Target_time'],index=False)

# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime as dt
from datetime import timedelta,time
import csv

# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers
es = Elasticsearch(hosts=['http://10.120.14.100:9200'],timeout=600)

# %%
from sqlalchemy import create_engine
#engine=create_engine('sqlite:///./cnblogblog.db',echo=True)
engine = create_engine('mysql+mysqlconnector://root:Lu,77251@10.120.14.100:3306/db_test')
engine
# Out:
# Engine(mysql+mysqlconnector://root:***@10.120.14.100:3306/db_test)

# %%
with open("CTtest","r",encoding="utf-8") as f:
    reader_it = csv.DictReader(f)
    helpers.bulk(es, reader_it, index='test-index', doc_type='my-type-100',request_timeout=600)

# %%
els_test3 = es.search(index='test-index',body={},size=10000)['hits']['hits']
els_test3
# Out:
# [{'_index': 'test-index',
#   '_type': 'my-type-100',
#   '_id': 'hJDKOGwB8TjaYqB7aboV',
#   '_score': 1.0,
#   '_source': {'CSDP': '1580',
#    'PNO': '45781885',
#    'CDATE': '2018-06-28 00:00:00',
#    'ITEM': '70022',
#    'SEQNO': '1070230891',
#    'SNO2': '1',
#    'SCRN': '2019-07-17 20:01:47',
#    'BDATE': '2018-06-28 10:01:00',
#    'EDATE': '2018-06-28 10:30:42',
#    'ORDERDR': '176',
#    'MD_NO': '405108',
#    'PP_NO': '40BRD0101-000008',
#    'MODEL_NAME': 'SOMATOM Definition Flash',
#    'STATION_NAME': 'CTAWP73463',
#    'PLACE': '4FCT2',
#    'CASENO': '111',
#    'LINKNO': '10572968566',
#    'AMOUNT': '3850.0',
#    'NHI_COST': '',
#    'IO': 'O',
#    'DEPT': '76',
#    'PRICE': '',
#    'UTIME': '2019-07-17 20:01:47',
#    'ITEM_CNT': '1',
#    'SEX': 'M',
#    'AGE': '43',
#    'POS': '',
#    'Tool': 'B099180',
#    'Target_time': '0 days 00:29:42.000000000'}},
#  {'_index': 'test-index',
#   '_type': 'my-type-100',
#   '_id': 'hpDKOGwB8TjaYqB7aboV',
# ...

# %%
from pandas.io.json import json_normalize
df1 = json_normalize(els_test3)
df1
# Out:
#                        _id      _index  _score _source.AGE _source.AMOUNT  \
# 0     hJDKOGwB8TjaYqB7aboV  test-index     1.0          43         3850.0
# 1     hpDKOGwB8TjaYqB7aboV  test-index     1.0          34         4675.0
# 2     iZDKOGwB8TjaYqB7aboV  test-index     1.0          70         3800.0
# 3     kZDKOGwB8TjaYqB7aboV  test-index     1.0          79         5035.0
# 4     kpDKOGwB8TjaYqB7aboV  test-index     1.0          55         3800.0
# 5     k5DKOGwB8TjaYqB7aboV  test-index     1.0          60         3800.0
# 6     lJDKOGwB8TjaYqB7aboV  test-index     1.0          54         5500.0
# 7     opDKOGwB8TjaYqB7aboV  test-index     1.0          77         5035.0
# 8     ppDKOGwB8TjaYqB7aboV  test-index     1.0          51         5035.0
# 9     qJDKOGwB8TjaYqB7aboV  test-index     1.0          67         3800.0
# 10    q5DKOGwB8TjaYqB7aboV  test-index     1.0          40         5500.0
# 11    r5DKOGwB8TjaYqB7aboV  test-index     1.0          46         5500.0
# ...

# %%
ct_csv.to_sql('CT_test',con=engine,if_exists='replace',index=False)
print('done')
# Out:
# done

# %%
sql = 'select * from CT_test WHERE AGE = 45;'
df_CT_test = pd.read_sql_query(sql,engine)
df_CT_test
# Out:
#       CSDP       PNO                CDATE   ITEM       SEQNO  SNO2  \
# 0     3580  19287136  2017-10-03 00:00:00  70022  2060179741     1
# 1     3580  35937597  2017-10-03 00:00:00  70022  2060179851     1
# 2     3580  36384282  2017-10-05 00:00:00  79993  2060181104     1
# 3     3580  35290788  2017-10-06 00:00:00  79994  2060181624     1
# 4     3580  51755306  2017-10-09 00:00:00  79993  2060183270     1
# 5     3580  30027299  2017-10-13 00:00:00  70008  2060185418     1
# 6     3580  30027299  2017-10-13 00:00:00  70022  2060185423     1
# 7     3580  19352413  2017-10-20 00:00:00  79993  2060189921     1
# 8     3580  35965743  2017-11-13 00:00:00  79993  2060204280     1
# 9     3580  37150620  2017-11-14 00:00:00  79993  2060205013     1
# 10    3580  37340178  2017-11-16 00:00:00  79993  2060206323     1
# 11    3580  51619264  2017-11-23 00:00:00  79993  2060210597     1
# 12    3580  30846257  2017-11-30 00:00:00  77292  2060214534     1
# ...

# %% [markdown]
# ### [TEST2] df_CT_test 和本機端的DF比較

# %%
df[df['AGE']==45]
#數量維持
# Out:
#        CSDP       PNO      CDATE   ITEM       SEQNO  SNO2                SCRN  \
# 22     3580  19287136 2017-10-03  70022  2060179741     1 2019-07-17 14:43:14
# 31     3580  35937597 2017-10-03  70022  2060179851     1 2019-07-17 14:43:23
# 51     3580  36384282 2017-10-05  79993  2060181104     1 2019-07-17 14:44:01
# 64     3580  35290788 2017-10-06  79994  2060181624     1 2019-07-17 14:44:14
# 107    3580  51755306 2017-10-09  79993  2060183270     1 2019-07-17 14:44:48
# 174    3580  30027299 2017-10-13  70008  2060185418     1 2019-07-17 14:46:09
# 175    3580  30027299 2017-10-13  70022  2060185423     1 2019-07-17 14:46:08
# 308    3580  19352413 2017-10-20  79993  2060189921     1 2019-07-17 14:47:50
# 667    3580  35965743 2017-11-13  79993  2060204280     1 2019-07-17 14:54:27
# 694    3580  37150620 2017-11-14  79993  2060205013     1 2019-07-17 14:55:06
# 750    3580  37340178 2017-11-16  79993  2060206323     1 2019-07-17 14:55:35
# ...
