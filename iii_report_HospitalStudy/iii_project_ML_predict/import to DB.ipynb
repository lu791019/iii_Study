# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime as dt
from datetime import timedelta,time

# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers
import csv
es = Elasticsearch(hosts=['http://10.120.14.100:9200'],timeout=600)

# %%
from sqlalchemy import create_engine
#engine=create_engine('sqlite:///./cnblogblog.db',echo=True)
engine = create_engine('mysql+mysqlconnector://root:Lu,77251@10.120.14.100:3306/db_test')
engine
# Out:
# Engine(mysql+mysqlconnector://root:***@10.120.14.100:3306/db_test)

# %% [markdown]
# ### Item_ListName 放進 MYSQL

# %%
dirname= 'C:/Users/Big data/iii_report_HospitalStudy/iii_project_ML_predict'

f_it = os.path.join(dirname,'Item_ListName')
it_csv = pd.read_csv(f_it)

it_csv.to_sql('IT_List_Cost',con=engine,if_exists='replace',index=False)
print('done')
# Out:
# "it_csv.to_sql('IT_List_Cost',con=engine,if_exists='replace',index=False)\nprint('done')"

# %%
it_csv.columns
# Out:
# Index(['ITEM', 'List_Name', 'Cost_Self'], dtype='object')

# %%
it_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5663 entries, 0 to 5662
# Data columns (total 3 columns):
# ITEM         5663 non-null object
# List_Name    5659 non-null object
# Cost_Self    5650 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 132.8+ KB

# %%
it_csv.to_csv('Item_ListName.csv',columns=['ITEM', 'List_Name', 'Cost_Self'],index=False)

# %% [markdown]
# ### Item_ListName 放進 Elasticsearch

# %%
it_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5663 entries, 0 to 5662
# Data columns (total 3 columns):
# ITEM         5663 non-null object
# List_Name    5659 non-null object
# Cost_Self    5650 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 132.8+ KB

# %%
import csv
with open("Item_ListName","r",encoding="utf-8") as f:
    reader_it = csv.DictReader(f)
    helpers.bulk(es, reader_it, index='ls-index', doc_type='my-type-1',request_timeout=100)

# %%
els_test1 = es.search(index='ls-index',body={},size=6000)['hits']['hits']
els_test1
# Out:
# [{'_index': 'ls-index',
#   '_type': 'my-type-1',
#   '_id': '0ZCiNmwB8TjaYqB74Dvi',
#   '_score': 1.0,
#   '_source': {'ITEM': '120032',
#    'List_Name': 'H1N1新型流感疫苗接種診察費',
#    'Cost_Self': '150.0'}},
#  {'_index': 'ls-index',
#   '_type': 'my-type-1',
#   '_id': '05CiNmwB8TjaYqB74Dvi',
#   '_score': 1.0,
#   '_source': {'ITEM': '12003C2',
#    'List_Name': 'OPDDRFEE一般門診診察費-開具連續2次以上慢性病連續處方箋本院自行調劑(合理量內)',
#    'Cost_Self': '530.0'}},
#  {'_index': 'ls-index',
#   '_type': 'my-type-1',
#   '_id': '1ZCiNmwB8TjaYqB74Dvi',
#   '_score': 1.0,
#   '_source': {'ITEM': '12003CG2',
#    'List_Name': 'OPDDRFEE一般門診診察費-開具連續2次以上慢性病連續處方箋交付藥局調劑(合理量內)',
#    'Cost_Self': '560.0'}},
#  {'_index': 'ls-index',
#   '_type': 'my-type-1',
#   '_id': '2ZCiNmwB8TjaYqB74Dvi',
#   '_score': 1.0,
#   '_source': {'ITEM': '12004',
#    'List_Name': 'EMGDRFEE急診醫師診察費',
#    'Cost_Self': '550.0'}},
#  {'_index': 'ls-index',
#   '_type': 'my-type-1',
#   '_id': '3ZCiNmwB8TjaYqB74Dvi',
#   '_score': 1.0,
# ...

# %%
from pandas.io.json import json_normalize
df1 = json_normalize(els_test1)
df1
# Out:
#                        _id    _index  _score _source.Cost_Self _source.ITEM  \
# 0     0ZCiNmwB8TjaYqB74Dvi  ls-index     1.0             150.0       120032
# 1     05CiNmwB8TjaYqB74Dvi  ls-index     1.0             530.0      12003C2
# 2     1ZCiNmwB8TjaYqB74Dvi  ls-index     1.0             560.0     12003CG2
# 3     2ZCiNmwB8TjaYqB74Dvi  ls-index     1.0             550.0        12004
# 4     3ZCiNmwB8TjaYqB74Dvi  ls-index     1.0             550.0       120044
# 5     5JCiNmwB8TjaYqB74Dvi  ls-index     1.0             708.0      1200462
# 6     85CiNmwB8TjaYqB74Dvi  ls-index     1.0             420.0      120049G
# 7     9pCiNmwB8TjaYqB74Dvi  ls-index     1.0             460.0       120056
# 8     -ZCiNmwB8TjaYqB74Dvi  ls-index     1.0             460.0      1200563
# 9     A5CiNmwB8TjaYqB74Dzj  ls-index     1.0             606.0     12006CG2
# 10    B5CiNmwB8TjaYqB74Dzj  ls-index     1.0            1200.0        12009
# ...

# %% [markdown]
# sql test

# %%
sql = 'select * from IT_List_Cost WHERE Cost_Self = 250;'
df_it_test = pd.read_sql_query(sql,engine)
df_it_test
# Out:
#        ITEM                                          List_Name  Cost_Self
# 0     11003                                   EMGRGST急診初診掛號手續費      250.0
# 1     11004                                EMGRGSTFEE急診複診掛號手續費      250.0
# 2     12003                                  OPDDRFEE複診一般醫師診察費      250.0
# 3    12003G                     OPDDRFEE一般門診診察費-處方交付藥局調劑(合理量內)      250.0
# 4     12013                                          基層院所門診診察費      250.0
# 5     12027                 OPDDRFEE一般門診診察費(金馬地區)--未開處方或處方自行調劑      250.0
# 6     12028                  OPDDRFEE一般門診診察費(山地離島)-未開處方或處方自行調劑      250.0
# 7     12070                                       牙科醫師診察費(尖石鄉)      250.0
# 8     12072                                   NURODRFEE牙科醫師診察費      250.0
# 9    12072G                                      牙科醫師診察費(交付處方)      250.0
# 10    12076                        牙科門診診察費(山地離島地區--處方交付特約藥局調劑)      250.0
# 11    12077                   牙科門診診察費(山地離島地區--未開處方或處方由本院所自行調劑)      250.0
# ...

# %% [markdown]
# ### Item_ListName

# %%
import pymongo
from pymongo import MongoClient
client = pymongo.MongoClient(host='10.120.14.100', port=27017,connect=False)

# %% [markdown]
# ### Dr_ORDR_DEPT放進SQL

# %%
dirname= 'C:/Users/Big data/iii_report_HospitalStudy/iii_project_ML_predict'

f_dr = os.path.join(dirname,'Doctor_merge_ORDERDR_Department')
dr_csv = pd.read_csv(f_dr)

dr_csv.to_sql('Dr_ORDR_DEPT',con=engine,if_exists='replace',index=False)
print('done')
# Out:
# done

# %%
dr_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 4 columns):
# Dr_Name       783 non-null object
# ORDERDR       780 non-null object
# Remarked      171 non-null object
# Department    782 non-null object
# dtypes: object(4)
# memory usage: 24.5+ KB

# %%
dr_csv.columns
# Out:
# Index(['Dr_Name', 'ORDERDR', 'Remarked', 'Department'], dtype='object')

# %% [markdown]
# sql test

# %%
sql = 'select * from Dr_ORDR_DEPT WHERE Department = "心臟內科(14)";'
df_dr_test = pd.read_sql_query(sql,engine)

# %% [markdown]
# ### Dr_ORDR_DEPT放進Elasticsearch

# %%
with open("Doctor_merge_ORDERDR_Department","r",encoding="utf-8") as f:
    reader_it = csv.DictReader(f)
    helpers.bulk(es, reader_it, index='dr-index', doc_type='my-type-2',request_timeout=100)

# %%
els_test2 = es.search(index='dr-index',body={},size=800)['hits']['hits']

# %%
from pandas.io.json import json_normalize
df2 = json_normalize(els_test2)
df2
# Out:
#                       _id    _index  _score _source.Department  \
# 0    5ZCjNmwB8TjaYqB74VGr  dr-index     1.0      內分泌暨新陳代謝科(12)
# 1    55CjNmwB8TjaYqB74VGr  dr-index     1.0      內分泌暨新陳代謝科(12)
# 2    65CjNmwB8TjaYqB74VGr  dr-index     1.0      內分泌暨新陳代謝科(12)
# 3    7JCjNmwB8TjaYqB74VGr  dr-index     1.0          胃腸肝膽科(13)
# 4    75CjNmwB8TjaYqB74VGr  dr-index     1.0          胃腸肝膽科(13)
# 5    -ZCjNmwB8TjaYqB74VGr  dr-index     1.0          胃腸肝膽科(13)
# 6    _ZCjNmwB8TjaYqB74VGr  dr-index     1.0           心臟內科(14)
# 7    BJCjNmwB8TjaYqB74VKr  dr-index     1.0           心臟內科(14)
# 8    EpCjNmwB8TjaYqB74VKr  dr-index     1.0           胸腔內科(15)
# 9    FJCjNmwB8TjaYqB74VKr  dr-index     1.0           胸腔內科(15)
# 10   F5CjNmwB8TjaYqB74VKr  dr-index     1.0           腎臟內科(16)
# 11   GZCjNmwB8TjaYqB74VKr  dr-index     1.0         血液暨腫瘤科(18)
# 12   LJCjNmwB8TjaYqB74VKr  dr-index     1.0            神經科(20)
# 13   LZCjNmwB8TjaYqB74VKr  dr-index     1.0            神經科(20)
# ...
